# %%
install.packages("climaemet")
# Out:
# Installing package into 'C:/Users/Reslan Al Tinawi/AppData/Local/R/win-library/4.3'
# (as 'lib' is unspecified)
# package 'climaemet' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Reslan Al Tinawi\AppData\Local\Temp\RtmpqqphIa\downloaded_packages

# %%
library(climaemet)
# Out:
# Warning message:
# "package 'climaemet' was built under R version 4.3.3"

# %%
## Use this function to register your API Key temporarly or permanently
aemet_api_key("eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJyZXNsYW4zMTIxQGdtYWlsLmNvbSIsImp0aSI6ImZhNWQwOGFhLTc1NzUtNGQ2Mi05ZGIxLTUyYjM5ZjBkYTlmZSIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNzIyNjkwMjYzLCJ1c2VySWQiOiJmYTVkMDhhYS03NTc1LTRkNjItOWRiMS01MmIzOWYwZGE5ZmUiLCJyb2xlIjoiIn0.WIqaJbiLtrwJx_I4VYGNZ1zaEt2qO0CIH2hq_xAypsQ", install = TRUE)
# Out:
# Error: An AEMET_API_KEY already exists. You can overwrite it with the argument overwrite=TRUE
# Traceback:
#
# 1. aemet_api_key("eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJyZXNsYW4zMTIxQGdtYWlsLmNvbSIsImp0aSI6ImZhNWQwOGFhLTc1NzUtNGQ2Mi05ZGIxLTUyYjM5ZjBkYTlmZSIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNzIyNjkwMjYzLCJ1c2VySWQiOiJmYTVkMDhhYS03NTc1LTRkNjItOWRiMS01MmIzOWYwZGE5ZmUiLCJyb2xlIjoiIn0.WIqaJbiLtrwJx_I4VYGNZ1zaEt2qO0CIH2hq_xAypsQ",
#  .     install = TRUE)
# 2. stop("An AEMET_API_KEY already exists. You can overwrite it with the ",
#  .     "argument overwrite=TRUE", call. = FALSE)

# %%
start_date <- "1998-01-01"  # Start date
end_date <- "2023-12-31"    # End date

# %%
# Fetch daily climatological data for all stations
daily_climatological_data <- aemet_daily_clim(
  start = start_date,
  end = end_date,
  verbose = TRUE
)
# Out:
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1998-01-01T00:00:00UTC/fechafin/1998-01-04T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 149
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/7e65f80b
#
# HTTP 200: Se han encontrado 845 climatologias diarias
#
# Remaining request count: 148
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1998-01-04T00:00:00UTC/fechafin/1998-01-18T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 147
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/e381a5d7
#
# HTTP 200: Se han encontrado 3215 climatologias diarias
#
# Remaining request count: 146
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1998-01-18T00:00:00UTC/fechafin/1998-02-01T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 145
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/7e1c3c8b
#
# HTTP 200: Se han encontrado 3225 climatologias diarias
#
# Remaining request count: 144
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1998-02-01T00:00:00UTC/fechafin/1998-02-15T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 143
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/ce48fdfe
#
# HTTP 200: Se han encontrado 3196 climatologias diarias
#
# Remaining request count: 142
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1998-02-15T00:00:00UTC/fechafin/1998-03-01T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 141
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/a0e1f6f6
#
# HTTP 200: Se han encontrado 3220 climatologias diarias
#
# Remaining request count: 140
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1998-03-01T00:00:00UTC/fechafin/1998-03-15T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 139
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/d59a4536
#
# HTTP 200: Se han encontrado 3239 climatologias diarias
#
# Remaining request count: 138
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1998-03-15T00:00:00UTC/fechafin/1998-03-29T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 137
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/db5b3fcd
#
# HTTP 200: Se han encontrado 3244 climatologias diarias
#
# Remaining request count: 136
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1998-03-29T00:00:00UTC/fechafin/1998-04-12T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 135
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/45fcafe4
#
# HTTP 200: Se han encontrado 3208 climatologias diarias
#
# Remaining request count: 134
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1998-04-12T00:00:00UTC/fechafin/1998-04-26T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 133
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/10be33d0
#
# HTTP 200: Se han encontrado 3291 climatologias diarias
#
# Remaining request count: 132
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1998-04-26T00:00:00UTC/fechafin/1998-05-10T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 131
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/f86ca5d4
#
# HTTP 200: Se han encontrado 3273 climatologias diarias
#
# Remaining request count: 130
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1998-05-10T00:00:00UTC/fechafin/1998-05-24T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 129
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/aa37456d
#
# HTTP 200: Se han encontrado 3295 climatologias diarias
#
# Remaining request count: 128
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1998-05-24T00:00:00UTC/fechafin/1998-06-07T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 127
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/291f404a
#
# HTTP 200: Se han encontrado 3278 climatologias diarias
#
# Remaining request count: 126
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1998-06-07T00:00:00UTC/fechafin/1998-06-21T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 125
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/14097f85
#
# HTTP 200: Se han encontrado 3302 climatologias diarias
#
# Remaining request count: 124
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1998-06-21T00:00:00UTC/fechafin/1998-07-05T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 123
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/a95f7e21
#
# HTTP 200: Se han encontrado 3277 climatologias diarias
#
# Remaining request count: 122
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1998-07-05T00:00:00UTC/fechafin/1998-07-19T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 121
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/ece291c4
#
# HTTP 200: Se han encontrado 3253 climatologias diarias
#
# Remaining request count: 120
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1998-07-19T00:00:00UTC/fechafin/1998-08-02T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 119
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/31982a51
#
# HTTP 200: Se han encontrado 3277 climatologias diarias
#
# Remaining request count: 118
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1998-08-02T00:00:00UTC/fechafin/1998-08-16T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 117
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/90f896fa
#
# HTTP 200: Se han encontrado 3268 climatologias diarias
#
# Remaining request count: 116
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1998-08-16T00:00:00UTC/fechafin/1998-08-30T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 115
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/bfa5c5e7
#
# HTTP 200: Se han encontrado 3261 climatologias diarias
#
# Remaining request count: 114
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1998-08-30T00:00:00UTC/fechafin/1998-09-13T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 113
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/6d630e5b
#
# HTTP 200: Se han encontrado 3255 climatologias diarias
#
# Remaining request count: 112
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1998-09-13T00:00:00UTC/fechafin/1998-09-27T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 111
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/3390710a
#
# HTTP 200: Se han encontrado 3234 climatologias diarias
#
# Remaining request count: 110
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1998-09-27T00:00:00UTC/fechafin/1998-10-11T23:59:59UTC/todasestaciones
#
# HTTP 429: Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto. Retrying...
#
# Waiting 2s for retry backoff ■■■■■■■■■■■■■■■■
#
# HTTP 200: exito
#
# Remaining request count: 149
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/584d212b
#
# HTTP 200: Se han encontrado 3281 climatologias diarias
#
# Remaining request count: 148
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1998-10-11T00:00:00UTC/fechafin/1998-10-25T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 147
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/0b28a4a0
#
# HTTP 200: Se han encontrado 3316 climatologias diarias
#
# Remaining request count: 146
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1998-10-25T00:00:00UTC/fechafin/1998-11-08T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 145
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/c3a7ddc1
#
# HTTP 200: Se han encontrado 3281 climatologias diarias
#
# Remaining request count: 144
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1998-11-08T00:00:00UTC/fechafin/1998-11-22T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 143
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/5a92c972
#
# HTTP 200: Se han encontrado 3276 climatologias diarias
#
# Remaining request count: 142
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1998-11-22T00:00:00UTC/fechafin/1998-12-06T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 141
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/dcf9f131
#
# HTTP 200: Se han encontrado 3244 climatologias diarias
#
# Remaining request count: 140
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1998-12-06T00:00:00UTC/fechafin/1998-12-20T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 139
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/c6807373
#
# HTTP 200: Se han encontrado 3227 climatologias diarias
#
# Remaining request count: 138
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1998-12-20T00:00:00UTC/fechafin/1999-01-03T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 137
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/c3acaf4a
#
# HTTP 200: Se han encontrado 3214 climatologias diarias
#
# Remaining request count: 136
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1999-01-03T00:00:00UTC/fechafin/1999-01-17T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 135
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/4f3645be
#
# HTTP 200: Se han encontrado 3221 climatologias diarias
#
# Remaining request count: 134
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1999-01-17T00:00:00UTC/fechafin/1999-01-31T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 133
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/a23f2842
#
# HTTP 200: Se han encontrado 3229 climatologias diarias
#
# Remaining request count: 132
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1999-01-31T00:00:00UTC/fechafin/1999-02-14T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 131
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/4aaf2152
#
# HTTP 200: Se han encontrado 3222 climatologias diarias
#
# Remaining request count: 130
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1999-02-14T00:00:00UTC/fechafin/1999-02-28T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 129
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/32a6e265
#
# HTTP 200: Se han encontrado 3274 climatologias diarias
#
# Remaining request count: 128
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1999-02-28T00:00:00UTC/fechafin/1999-03-14T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 127
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/cb3dc152
#
# HTTP 200: Se han encontrado 3229 climatologias diarias
#
# Remaining request count: 126
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1999-03-14T00:00:00UTC/fechafin/1999-03-28T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 125
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/272c7d9e
#
# HTTP 200: Se han encontrado 3235 climatologias diarias
#
# Remaining request count: 124
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1999-03-28T00:00:00UTC/fechafin/1999-04-11T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 123
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/fa675887
#
# HTTP 200: Se han encontrado 3238 climatologias diarias
#
# Remaining request count: 122
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1999-04-11T00:00:00UTC/fechafin/1999-04-25T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 121
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/b012da69
#
# HTTP 200: Se han encontrado 3239 climatologias diarias
#
# Remaining request count: 120
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1999-04-25T00:00:00UTC/fechafin/1999-05-09T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 119
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/48119ab8
#
# HTTP 200: Se han encontrado 3208 climatologias diarias
#
# Remaining request count: 118
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1999-05-09T00:00:00UTC/fechafin/1999-05-23T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 117
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/3b3a63ab
#
# HTTP 200: Se han encontrado 3248 climatologias diarias
#
# Remaining request count: 116
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1999-05-23T00:00:00UTC/fechafin/1999-06-06T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 115
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/90036b85
#
# HTTP 200: Se han encontrado 3249 climatologias diarias
#
# Remaining request count: 114
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1999-06-06T00:00:00UTC/fechafin/1999-06-20T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 113
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/4727fb26
#
# HTTP 200: Se han encontrado 3256 climatologias diarias
#
# Remaining request count: 112
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1999-06-20T00:00:00UTC/fechafin/1999-07-04T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 111
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/45b8d32f
#
# HTTP 200: Se han encontrado 3283 climatologias diarias
#
# Remaining request count: 110
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1999-07-04T00:00:00UTC/fechafin/1999-07-18T23:59:59UTC/todasestaciones
#
# HTTP 429: Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto. Retrying...
#
# Waiting 3s for retry backoff ■■■■■■■■■■■
# Waiting 3s for retry backoff ■■■■■■■■■■■■
# Waiting 3s for retry backoff ■■■■■■■■■■■■■
# Waiting 3s for retry backoff ■■■■■■■■■■■■■■■■
# Waiting 3s for retry backoff ■■■■■■■■■■■■■■■■■■■■
# Waiting 3s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 3s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 3s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 3s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 3s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■
#
# Waiting 3s for retry backoff ■■■■■■■■■■■■
# Waiting 3s for retry backoff ■■■■■■■■■■■■■■
# Waiting 3s for retry backoff ■■■■■■■■■■■■■■■
# Waiting 3s for retry backoff ■■■■■■■■■■■■■■■■■■■■■
# Waiting 3s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 3s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 3s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 3s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■
#
# Waiting 12s for retry backoff ■■■■
# Waiting 12s for retry backoff ■■■■
# Waiting 12s for retry backoff ■■■■
# Waiting 12s for retry backoff ■■■■■
# Waiting 12s for retry backoff ■■■■■
# Waiting 12s for retry backoff ■■■■■■
# Waiting 12s for retry backoff ■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■■■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■■■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■■■■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■■■■■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■■■■■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 12s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■
#
# HTTP 200: exito
#
# Remaining request count: 149
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/5ce6ee83
#
# HTTP 200: Se han encontrado 3261 climatologias diarias
#
# Remaining request count: 148
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1999-07-18T00:00:00UTC/fechafin/1999-08-01T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 147
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/e2483517
#
# HTTP 200: Se han encontrado 3257 climatologias diarias
#
# Remaining request count: 146
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1999-08-01T00:00:00UTC/fechafin/1999-08-15T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 145
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/8e62307d
#
# HTTP 200: Se han encontrado 3210 climatologias diarias
#
# Remaining request count: 144
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1999-08-15T00:00:00UTC/fechafin/1999-08-29T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 143
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/73c1e600
#
# HTTP 200: Se han encontrado 3236 climatologias diarias
#
# Remaining request count: 142
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1999-08-29T00:00:00UTC/fechafin/1999-09-12T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 141
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/3a60939c
#
# HTTP 200: Se han encontrado 3175 climatologias diarias
#
# Remaining request count: 140
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1999-09-12T00:00:00UTC/fechafin/1999-09-26T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 139
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/29c92558
#
# HTTP 200: Se han encontrado 3144 climatologias diarias
#
# Remaining request count: 138
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1999-09-26T00:00:00UTC/fechafin/1999-10-10T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 137
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/c8263015
#
# HTTP 200: Se han encontrado 3196 climatologias diarias
#
# Remaining request count: 136
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1999-10-10T00:00:00UTC/fechafin/1999-10-24T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 135
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/4b2a23f6
#
# HTTP 200: Se han encontrado 3197 climatologias diarias
#
# Remaining request count: 134
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1999-10-24T00:00:00UTC/fechafin/1999-11-07T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 133
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/c8293114
#
# HTTP 200: Se han encontrado 3222 climatologias diarias
#
# Remaining request count: 132
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1999-11-07T00:00:00UTC/fechafin/1999-11-21T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 131
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/edef2ff1
#
# HTTP 200: Se han encontrado 3281 climatologias diarias
#
# Remaining request count: 130
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1999-11-21T00:00:00UTC/fechafin/1999-12-05T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 129
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/e34ab6e6
#
# HTTP 200: Se han encontrado 3178 climatologias diarias
#
# Remaining request count: 128
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1999-12-05T00:00:00UTC/fechafin/1999-12-19T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 127
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/b2aef957
#
# HTTP 200: Se han encontrado 3124 climatologias diarias
#
# Remaining request count: 126
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/1999-12-19T00:00:00UTC/fechafin/2000-01-02T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 125
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/1a151d5c
#
# HTTP 200: Se han encontrado 3104 climatologias diarias
#
# Remaining request count: 124
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2000-01-02T00:00:00UTC/fechafin/2000-01-16T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 123
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/c218543a
#
# HTTP 200: Se han encontrado 3122 climatologias diarias
#
# Remaining request count: 122
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2000-01-16T00:00:00UTC/fechafin/2000-01-30T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 121
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/dcab3430
#
# HTTP 200: Se han encontrado 3177 climatologias diarias
#
# Remaining request count: 120
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2000-01-30T00:00:00UTC/fechafin/2000-02-13T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 119
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/37218ad9
#
# HTTP 200: Se han encontrado 3220 climatologias diarias
#
# Remaining request count: 118
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2000-02-13T00:00:00UTC/fechafin/2000-02-27T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 117
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/87d4a9ce
#
# HTTP 200: Se han encontrado 3223 climatologias diarias
#
# Remaining request count: 116
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2000-02-27T00:00:00UTC/fechafin/2000-03-12T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 115
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/0ce3eb43
#
# HTTP 200: Se han encontrado 3249 climatologias diarias
#
# Remaining request count: 114
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2000-03-12T00:00:00UTC/fechafin/2000-03-26T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 113
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/8edac364
#
# HTTP 200: Se han encontrado 3237 climatologias diarias
#
# Remaining request count: 112
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2000-03-26T00:00:00UTC/fechafin/2000-04-09T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 111
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/1c65793f
#
# HTTP 200: Se han encontrado 3226 climatologias diarias
#
# Remaining request count: 110
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2000-04-09T00:00:00UTC/fechafin/2000-04-23T23:59:59UTC/todasestaciones
#
# HTTP 429: Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto. Retrying...
#
# Waiting 7s for retry backoff ■■■■■■
# Waiting 7s for retry backoff ■■■■■■■
# Waiting 7s for retry backoff ■■■■■■■■
# Waiting 7s for retry backoff ■■■■■■■■■
# Waiting 7s for retry backoff ■■■■■■■■■■
# Waiting 7s for retry backoff ■■■■■■■■■■■
# Waiting 7s for retry backoff ■■■■■■■■■■■■
# Waiting 7s for retry backoff ■■■■■■■■■■■■■
# Waiting 7s for retry backoff ■■■■■■■■■■■■■■
# Waiting 7s for retry backoff ■■■■■■■■■■■■■■■
# Waiting 7s for retry backoff ■■■■■■■■■■■■■■■■
# Waiting 7s for retry backoff ■■■■■■■■■■■■■■■■■
# Waiting 7s for retry backoff ■■■■■■■■■■■■■■■■■■
# Waiting 7s for retry backoff ■■■■■■■■■■■■■■■■■■■
# Waiting 7s for retry backoff ■■■■■■■■■■■■■■■■■■■■
# Waiting 7s for retry backoff ■■■■■■■■■■■■■■■■■■■■■
# Waiting 7s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■
# Waiting 7s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 7s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 7s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 7s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 7s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 7s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 7s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 7s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■
#
# HTTP 200: exito
#
# Remaining request count: 149
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/469fe200
#
# HTTP 200: Se han encontrado 3217 climatologias diarias
#
# Remaining request count: 148
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2000-04-23T00:00:00UTC/fechafin/2000-05-07T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 147
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/ca52a17d
#
# HTTP 200: Se han encontrado 3214 climatologias diarias
#
# Remaining request count: 146
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2000-05-07T00:00:00UTC/fechafin/2000-05-21T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 145
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/3f4383bd
#
# HTTP 200: Se han encontrado 3165 climatologias diarias
#
# Remaining request count: 144
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2000-05-21T00:00:00UTC/fechafin/2000-06-04T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 143
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/d9ce4da9
#
# HTTP 200: Se han encontrado 3172 climatologias diarias
#
# Remaining request count: 142
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2000-06-04T00:00:00UTC/fechafin/2000-06-18T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 141
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/7bdfb89c
#
# HTTP 200: Se han encontrado 3162 climatologias diarias
#
# Remaining request count: 140
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2000-06-18T00:00:00UTC/fechafin/2000-07-02T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 139
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/c3f5a79c
#
# HTTP 200: Se han encontrado 3213 climatologias diarias
#
# Remaining request count: 138
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2000-07-02T00:00:00UTC/fechafin/2000-07-16T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 137
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/d15a2b67
#
# HTTP 200: Se han encontrado 3229 climatologias diarias
#
# Remaining request count: 136
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2000-07-16T00:00:00UTC/fechafin/2000-07-30T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 135
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/a2eee7f8
#
# HTTP 200: Se han encontrado 3242 climatologias diarias
#
# Remaining request count: 134
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2000-07-30T00:00:00UTC/fechafin/2000-08-13T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 133
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/1a4d5676
#
# HTTP 200: Se han encontrado 3285 climatologias diarias
#
# Remaining request count: 132
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2000-08-13T00:00:00UTC/fechafin/2000-08-27T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 131
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/2b1d8b05
#
# HTTP 200: Se han encontrado 3263 climatologias diarias
#
# Remaining request count: 130
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2000-08-27T00:00:00UTC/fechafin/2000-09-10T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 129
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/ed100112
#
# HTTP 200: Se han encontrado 3282 climatologias diarias
#
# Remaining request count: 128
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2000-09-10T00:00:00UTC/fechafin/2000-09-24T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 127
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/70e2c8e1
#
# HTTP 200: Se han encontrado 3286 climatologias diarias
#
# Remaining request count: 126
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2000-09-24T00:00:00UTC/fechafin/2000-10-08T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 125
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/91c4a665
#
# HTTP 200: Se han encontrado 3288 climatologias diarias
#
# Remaining request count: 124
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2000-10-08T00:00:00UTC/fechafin/2000-10-22T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 123
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/5bf33094
#
# HTTP 200: Se han encontrado 3318 climatologias diarias
#
# Remaining request count: 122
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2000-10-22T00:00:00UTC/fechafin/2000-11-05T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 121
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/ea7ea8d6
#
# HTTP 200: Se han encontrado 3311 climatologias diarias
#
# Remaining request count: 120
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2000-11-05T00:00:00UTC/fechafin/2000-11-19T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 119
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/78da5678
#
# HTTP 200: Se han encontrado 3264 climatologias diarias
#
# Remaining request count: 118
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2000-11-19T00:00:00UTC/fechafin/2000-12-03T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 117
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/ec1235e0
#
# HTTP 200: Se han encontrado 3263 climatologias diarias
#
# Remaining request count: 116
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2000-12-03T00:00:00UTC/fechafin/2000-12-17T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 115
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/b5f87628
#
# HTTP 200: Se han encontrado 3225 climatologias diarias
#
# Remaining request count: 114
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2000-12-17T00:00:00UTC/fechafin/2000-12-31T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 113
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/e74f53cf
#
# HTTP 200: Se han encontrado 3247 climatologias diarias
#
# Remaining request count: 112
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2000-12-31T00:00:00UTC/fechafin/2001-01-14T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 111
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/b5561edc
#
# HTTP 200: Se han encontrado 3465 climatologias diarias
#
# Remaining request count: 110
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2001-01-14T00:00:00UTC/fechafin/2001-01-28T23:59:59UTC/todasestaciones
#
# HTTP 429: Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto. Retrying...
#
# Waiting 4s for retry backoff ■■■■■■■■■■
# Waiting 4s for retry backoff ■■■■■■■■■■■■
# Waiting 4s for retry backoff ■■■■■■■■■■■■■■
# Waiting 4s for retry backoff ■■■■■■■■■■■■■■■
# Waiting 4s for retry backoff ■■■■■■■■■■■■■■■■■■■■
# Waiting 4s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■
# Waiting 4s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 4s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 4s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 4s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■■■■■■
#
# Waiting 5s for retry backoff ■■■■■■■
# Waiting 5s for retry backoff ■■■■■■■■
# Waiting 5s for retry backoff ■■■■■■■■■■
# Waiting 5s for retry backoff ■■■■■■■■■■■
# Waiting 5s for retry backoff ■■■■■■■■■■■■
# Waiting 5s for retry backoff ■■■■■■■■■■■■■■
# Waiting 5s for retry backoff ■■■■■■■■■■■■■■■
# Waiting 5s for retry backoff ■■■■■■■■■■■■■■■■■
# Waiting 5s for retry backoff ■■■■■■■■■■■■■■■■■■
# Waiting 5s for retry backoff ■■■■■■■■■■■■■■■■■■■
# Waiting 5s for retry backoff ■■■■■■■■■■■■■■■■■■■■
# Waiting 5s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■
# Waiting 5s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 5s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 5s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 5s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 5s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 5s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■
#
# Waiting 8s for retry backoff ■■■■■
# Waiting 8s for retry backoff ■■■■■
# Waiting 8s for retry backoff ■■■■■■
# Waiting 8s for retry backoff ■■■■■■■
# Waiting 8s for retry backoff ■■■■■■■■
# Waiting 8s for retry backoff ■■■■■■■■
# Waiting 8s for retry backoff ■■■■■■■■■
# Waiting 8s for retry backoff ■■■■■■■■■■
# Waiting 8s for retry backoff ■■■■■■■■■■
# Waiting 8s for retry backoff ■■■■■■■■■■■
# Waiting 8s for retry backoff ■■■■■■■■■■■■
# Waiting 8s for retry backoff ■■■■■■■■■■■■■
# Waiting 8s for retry backoff ■■■■■■■■■■■■■■
# Waiting 8s for retry backoff ■■■■■■■■■■■■■■■
# Waiting 8s for retry backoff ■■■■■■■■■■■■■■■
# Waiting 8s for retry backoff ■■■■■■■■■■■■■■■■
# Waiting 8s for retry backoff ■■■■■■■■■■■■■■■■■
# Waiting 8s for retry backoff ■■■■■■■■■■■■■■■■■■
# Waiting 8s for retry backoff ■■■■■■■■■■■■■■■■■■■
# Waiting 8s for retry backoff ■■■■■■■■■■■■■■■■■■■
# Waiting 8s for retry backoff ■■■■■■■■■■■■■■■■■■■■
# Waiting 8s for retry backoff ■■■■■■■■■■■■■■■■■■■■■
# Waiting 8s for retry backoff ■■■■■■■■■■■■■■■■■■■■■
# Waiting 8s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■
# Waiting 8s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 8s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 8s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 8s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 8s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 8s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 8s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 8s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 8s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■
# Waiting 8s for retry backoff ■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■
#
# HTTP 200: exito
#
# Remaining request count: 149
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/655a8d8b
#
# HTTP 200: Se han encontrado 3607 climatologias diarias
#
# Remaining request count: 148
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2001-01-28T00:00:00UTC/fechafin/2001-02-11T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 147
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/1a27954c
#
# HTTP 200: Se han encontrado 3610 climatologias diarias
#
# Remaining request count: 146
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2001-02-11T00:00:00UTC/fechafin/2001-02-25T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 145
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/47cab268
#
# HTTP 200: Se han encontrado 3628 climatologias diarias
#
# Remaining request count: 144
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2001-02-25T00:00:00UTC/fechafin/2001-03-11T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 143
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/09070101
#
# HTTP 200: Se han encontrado 3600 climatologias diarias
#
# Remaining request count: 142
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2001-03-11T00:00:00UTC/fechafin/2001-03-25T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 141
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/5a37f77c
#
# HTTP 200: Se han encontrado 3618 climatologias diarias
#
# Remaining request count: 140
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2001-03-25T00:00:00UTC/fechafin/2001-04-08T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 139
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/db9378b6
#
# HTTP 200: Se han encontrado 3621 climatologias diarias
#
# Remaining request count: 138
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2001-04-08T00:00:00UTC/fechafin/2001-04-22T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 137
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/78693e2d
#
# HTTP 200: Se han encontrado 3596 climatologias diarias
#
# Remaining request count: 136
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2001-04-22T00:00:00UTC/fechafin/2001-05-06T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 135
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/4d890c0a
#
# HTTP 200: Se han encontrado 3619 climatologias diarias
#
# Remaining request count: 134
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2001-05-06T00:00:00UTC/fechafin/2001-05-20T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 133
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/95a394af
#
# HTTP 200: Se han encontrado 3602 climatologias diarias
#
# Remaining request count: 132
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2001-05-20T00:00:00UTC/fechafin/2001-06-03T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 131
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/92853071
#
# HTTP 200: Se han encontrado 3586 climatologias diarias
#
# Remaining request count: 130
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2001-06-03T00:00:00UTC/fechafin/2001-06-17T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 129
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/47a2fd9c
#
# HTTP 200: Se han encontrado 3650 climatologias diarias
#
# Remaining request count: 128
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2001-06-17T00:00:00UTC/fechafin/2001-07-01T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 127
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/5d0a3a01
#
# HTTP 200: Se han encontrado 3641 climatologias diarias
#
# Remaining request count: 126
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2001-07-01T00:00:00UTC/fechafin/2001-07-15T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 125
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/ba8f16f0
#
# HTTP 200: Se han encontrado 3578 climatologias diarias
#
# Remaining request count: 124
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2001-07-15T00:00:00UTC/fechafin/2001-07-29T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 123
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/41df6d4f
#
# HTTP 200: Se han encontrado 3600 climatologias diarias
#
# Remaining request count: 122
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2001-07-29T00:00:00UTC/fechafin/2001-08-12T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 121
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/b2f410e1
#
# HTTP 200: Se han encontrado 3594 climatologias diarias
#
# Remaining request count: 120
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2001-08-12T00:00:00UTC/fechafin/2001-08-26T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# ...
#
# HTTP 200: exito
#
# Remaining request count: 135
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/b0a5a28f
#
# HTTP 200: Se han encontrado 13030 climatologias diarias
#
# Remaining request count: 134
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2022-06-19T00:00:00UTC/fechafin/2022-07-03T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 133
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/0e4e8370
#
# HTTP 200: Se han encontrado 13039 climatologias diarias
#
# Remaining request count: 132
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2022-07-03T00:00:00UTC/fechafin/2022-07-17T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 131
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/affeac12
#
# HTTP 200: Se han encontrado 13056 climatologias diarias
#
# Remaining request count: 130
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2022-07-17T00:00:00UTC/fechafin/2022-07-31T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 149
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/0260a99f
#
# HTTP 200: Se han encontrado 13046 climatologias diarias
#
# Remaining request count: 148
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2022-07-31T00:00:00UTC/fechafin/2022-08-14T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 147
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/508ed429
#
# HTTP 200: Se han encontrado 13041 climatologias diarias
#
# Remaining request count: 146
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2022-08-14T00:00:00UTC/fechafin/2022-08-28T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 145
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/83b211c2
#
# HTTP 200: Se han encontrado 13061 climatologias diarias
#
# Remaining request count: 144
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2022-08-28T00:00:00UTC/fechafin/2022-09-11T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 143
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/165f4ea4
#
# HTTP 200: Se han encontrado 13018 climatologias diarias
#
# Remaining request count: 142
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2022-09-11T00:00:00UTC/fechafin/2022-09-25T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 141
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/7d4b4dba
#
# HTTP 200: Se han encontrado 13037 climatologias diarias
#
# Remaining request count: 140
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2022-09-25T00:00:00UTC/fechafin/2022-10-09T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 139
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/eb5ce863
#
# HTTP 200: Se han encontrado 13076 climatologias diarias
#
# Remaining request count: 138
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2022-10-09T00:00:00UTC/fechafin/2022-10-23T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 137
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/85ff1525
#
# HTTP 200: Se han encontrado 13031 climatologias diarias
#
# Remaining request count: 136
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2022-10-23T00:00:00UTC/fechafin/2022-11-06T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 135
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/a11f4832
#
# HTTP 200: Se han encontrado 13029 climatologias diarias
#
# Remaining request count: 134
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2022-11-06T00:00:00UTC/fechafin/2022-11-20T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 133
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/81742b56
#
# HTTP 200: Se han encontrado 13028 climatologias diarias
#
# Remaining request count: 132
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2022-11-20T00:00:00UTC/fechafin/2022-12-04T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 131
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/ab7e07de
#
# HTTP 200: Se han encontrado 13087 climatologias diarias
#
# Remaining request count: 130
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2022-12-04T00:00:00UTC/fechafin/2022-12-18T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 129
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/210874a3
#
# HTTP 200: Se han encontrado 13024 climatologias diarias
#
# Remaining request count: 128
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2022-12-18T00:00:00UTC/fechafin/2023-01-01T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 149
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/d336773e
#
# HTTP 200: Se han encontrado 13047 climatologias diarias
#
# Remaining request count: 148
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2023-01-01T00:00:00UTC/fechafin/2023-01-15T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 147
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/024d9314
#
# HTTP 200: Se han encontrado 13075 climatologias diarias
#
# Remaining request count: 146
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2023-01-15T00:00:00UTC/fechafin/2023-01-29T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 145
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/7d581da6
#
# HTTP 200: Se han encontrado 13061 climatologias diarias
#
# Remaining request count: 144
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2023-01-29T00:00:00UTC/fechafin/2023-02-12T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 143
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/46b3eedc
#
# HTTP 200: Se han encontrado 13146 climatologias diarias
#
# Remaining request count: 142
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2023-02-12T00:00:00UTC/fechafin/2023-02-26T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 141
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/cf125fd7
#
# HTTP 200: Se han encontrado 13154 climatologias diarias
#
# Remaining request count: 140
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2023-02-26T00:00:00UTC/fechafin/2023-03-12T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 139
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/ecea419d
#
# HTTP 200: Se han encontrado 13153 climatologias diarias
#
# Remaining request count: 138
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2023-03-12T00:00:00UTC/fechafin/2023-03-26T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 137
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/d4805f18
#
# HTTP 200: Se han encontrado 13149 climatologias diarias
#
# Remaining request count: 136
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2023-03-26T00:00:00UTC/fechafin/2023-04-09T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 135
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/f3fafcbc
#
# HTTP 200: Se han encontrado 13147 climatologias diarias
#
# Remaining request count: 134
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2023-04-09T00:00:00UTC/fechafin/2023-04-23T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 133
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/6c695c70
#
# HTTP 200: Se han encontrado 13134 climatologias diarias
#
# Remaining request count: 132
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2023-04-23T00:00:00UTC/fechafin/2023-05-07T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 131
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/eb17967c
#
# HTTP 200: Se han encontrado 13087 climatologias diarias
#
# Remaining request count: 130
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2023-05-07T00:00:00UTC/fechafin/2023-05-21T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 149
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/d087c119
#
# HTTP 200: Se han encontrado 13018 climatologias diarias
#
# Remaining request count: 148
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2023-05-21T00:00:00UTC/fechafin/2023-06-04T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 147
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/b700994a
#
# HTTP 200: Se han encontrado 12937 climatologias diarias
#
# Remaining request count: 146
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2023-06-04T00:00:00UTC/fechafin/2023-06-18T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 145
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/9156407d
#
# HTTP 200: Se han encontrado 12999 climatologias diarias
#
# Remaining request count: 144
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2023-06-18T00:00:00UTC/fechafin/2023-07-02T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 143
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/8c9d6495
#
# HTTP 200: Se han encontrado 13053 climatologias diarias
#
# Remaining request count: 142
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2023-07-02T00:00:00UTC/fechafin/2023-07-16T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 141
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/d29fb38f
#
# HTTP 200: Se han encontrado 13200 climatologias diarias
#
# Remaining request count: 140
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2023-07-16T00:00:00UTC/fechafin/2023-07-30T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 139
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/274edbf3
#
# HTTP 200: Se han encontrado 13254 climatologias diarias
#
# Remaining request count: 138
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2023-07-30T00:00:00UTC/fechafin/2023-08-13T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 137
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/dec4e2fb
#
# HTTP 200: Se han encontrado 13268 climatologias diarias
#
# Remaining request count: 136
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2023-08-13T00:00:00UTC/fechafin/2023-08-27T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 135
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/d22c5c8b
#
# HTTP 200: Se han encontrado 13253 climatologias diarias
#
# Remaining request count: 134
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2023-08-27T00:00:00UTC/fechafin/2023-09-10T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 133
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/e8cb5ef0
#
# HTTP 200: Se han encontrado 13212 climatologias diarias
#
# Remaining request count: 132
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2023-09-10T00:00:00UTC/fechafin/2023-09-24T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 131
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/bb1e287d
#
# HTTP 200: Se han encontrado 13240 climatologias diarias
#
# Remaining request count: 130
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2023-09-24T00:00:00UTC/fechafin/2023-10-08T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 129
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/8de31880
#
# HTTP 200: Se han encontrado 13293 climatologias diarias
#
# Remaining request count: 128
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2023-10-08T00:00:00UTC/fechafin/2023-10-22T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 127
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/c6597f8e
#
# HTTP 200: Se han encontrado 13276 climatologias diarias
#
# Remaining request count: 149
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2023-10-22T00:00:00UTC/fechafin/2023-11-05T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 148
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/df28ebc6
#
# HTTP 200: Se han encontrado 13217 climatologias diarias
#
# Remaining request count: 147
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2023-11-05T00:00:00UTC/fechafin/2023-11-19T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 146
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/c4af292f
#
# HTTP 200: Se han encontrado 13233 climatologias diarias
#
# Remaining request count: 145
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2023-11-19T00:00:00UTC/fechafin/2023-12-03T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 144
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/328ce3c7
#
# HTTP 200: Se han encontrado 13280 climatologias diarias
#
# Remaining request count: 143
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2023-12-03T00:00:00UTC/fechafin/2023-12-17T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 142
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/9c751ff3
#
# HTTP 200: Se han encontrado 13306 climatologias diarias
#
# Remaining request count: 141
#
#
# Requesting https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2023-12-17T00:00:00UTC/fechafin/2023-12-31T23:59:59UTC/todasestaciones
#
# HTTP 200: exito
#
# Remaining request count: 140
#
#
# -----Requesting data-----
#
#
# Requesting https://opendata.aemet.es/opendata/sh/6c6165a6
#
# HTTP 200: Se han encontrado 13338 climatologias diarias
#
# Remaining request count: 139

# %%
head(daily_climatological_data)
# Out:
#   fecha      indicativo nombre               provincia     altitud tmed prec
# 1 1998-01-01 9394X      CALATAYUD            ZARAGOZA      582      6.5 0,0
# 2 1998-01-01 B434X      PORTOCOLOM           ILLES BALEARS  17     13.0 0,6
# 3 1998-01-01 8293X      XÀTIVA               VALENCIA       88      9.1 5,3
# 4 1998-01-01 2400E      AUTILLA DEL PINO     PALENCIA      874      0.6 0,0
# 5 1998-01-01 2755X      BENAVENTE            ZAMORA        715      3.0 0,0
# 6 1998-01-01 8500A      CASTELLÓ - ALMASSORA CASTELLON      43     10.0 2,1
#   tmin horatmin tmax ⋯ hrMedia presMax horaPresMax presMin horaPresMin hrMax
# 1  2.8 07:30    10.2 ⋯ NA          NA  NA              NA  NA          NA
# 2 10.3 02:40    15.8 ⋯ 90          NA  NA              NA  NA          NA
# 3  7.4 08:40    10.8 ⋯ NA          NA  NA              NA  NA          NA
# 4 -2.9 06:30     4.2 ⋯ 87       916.8  Varias       911.9  00          98
# 5 -2.3 07:50     8.2 ⋯ 66          NA  NA              NA  NA          88
# 6  8.4 05:00    11.6 ⋯ 73      1012.9  23          1004.9  01          NA
#   horaHrMax hrMin horaHrMin sol
# 1 NA        NA    NA        NA
# 2 NA        NA    NA        NA
# 3 NA        NA    NA        NA
# 4 07:00     77    Varias    NA
# 5 08:25     45    Varias    NA
# 6 NA        NA    NA         0

# %%
write.csv(daily_climatological_data, "../data/daily_climatological_data-with-r.csv", row.names = FALSE)
